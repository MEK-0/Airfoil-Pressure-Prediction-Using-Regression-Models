# %% [markdown]
# # Evaluation Visuals Random Forest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.metrics import mean_squared_error , mean_absolute_error,r2_score
import os

# %%
# %run ./03_RandomForest.ipynb
# Out:
# R2 Skoru: 0.8974898440626446
# MAE: 1.643327056535794
# MSE: 5.135613040829278
# R2 scores in each layer:[0.80523277 0.80563111 0.64670432 0.55641248 0.6248602 ]
# Cross-verification R2 average:0.6878
# Cross-verification R2 standard deviation:0.1006
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END bootstrap=True, max_depth=38, max_features=0.6, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   0.4s
# [CV] END bootstrap=True, max_depth=38, max_features=0.6, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   0.4s
# [CV] END bootstrap=True, max_depth=38, max_features=0.6, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   0.4s
# [CV] END bootstrap=True, max_depth=38, max_features=0.6, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=True, max_depth=38, max_features=0.6, min_samples_leaf=8, min_samples_split=8, n_estimators=221; total time=   0.5s
# [CV] END bootstrap=True, max_depth=32, max_features=0.6, min_samples_leaf=8, min_samples_split=5, n_estimators=459; total time=   0.7s
# [CV] END bootstrap=True, max_depth=32, max_features=0.6, min_samples_leaf=8, min_samples_split=5, n_estimators=459; total time=   0.7s
# [CV] END bootstrap=True, max_depth=32, max_features=0.6, min_samples_leaf=8, min_samples_split=5, n_estimators=459; total time=   0.7s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   0.3s
# [CV] END bootstrap=True, max_depth=32, max_features=0.6, min_samples_leaf=8, min_samples_split=5, n_estimators=459; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   0.4s
# [CV] END bootstrap=True, max_depth=32, max_features=0.6, min_samples_leaf=8, min_samples_split=5, n_estimators=459; total time=   0.5s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   0.3s
# [CV] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=154; total time=   0.1s
# [CV] END bootstrap=False, max_depth=12, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=443; total time=   0.4s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   0.4s
# [CV] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=154; total time=   0.1s
# [CV] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=154; total time=   0.1s
# [CV] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=154; total time=   0.1s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   0.4s
# [CV] END bootstrap=False, max_depth=34, max_features=sqrt, min_samples_leaf=3, min_samples_split=13, n_estimators=154; total time=   0.2s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   0.1s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   0.1s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   0.2s
# [CV] END bootstrap=False, max_depth=39, max_features=log2, min_samples_leaf=2, min_samples_split=2, n_estimators=413; total time=   0.4s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   0.1s
# [CV] END bootstrap=False, max_depth=12, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=120; total time=   0.1s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.3s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=439; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.3s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=439; total time=   0.3s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=439; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.4s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=341; total time=   0.4s
# [CV] END bootstrap=False, max_depth=16, max_features=0.8, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=   0.1s
# [CV] END bootstrap=False, max_depth=16, max_features=0.8, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=   0.1s
# [CV] END bootstrap=False, max_depth=16, max_features=0.8, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=   0.1s
# [CV] END bootstrap=False, max_depth=16, max_features=0.8, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=   0.1s
# [CV] END bootstrap=False, max_depth=16, max_features=0.8, min_samples_leaf=8, min_samples_split=16, n_estimators=134; total time=   0.2s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=439; total time=   0.4s
# [CV] END bootstrap=False, max_depth=18, max_features=log2, min_samples_leaf=5, min_samples_split=3, n_estimators=439; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=317; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=317; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=False, max_depth=26, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   0.5s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=False, max_depth=26, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   0.5s
# [CV] END bootstrap=False, max_depth=26, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   0.6s
# [CV] END bootstrap=False, max_depth=26, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   0.6s
# [CV] END bootstrap=False, max_depth=26, max_features=0.8, min_samples_leaf=2, min_samples_split=9, n_estimators=487; total time=   0.6s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=19, n_estimators=317; total time=   0.2s
# [CV] END bootstrap=False, max_depth=43, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=450; total time=   0.3s
# [CV] END bootstrap=False, max_depth=43, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=450; total time=   0.3s
# [CV] END bootstrap=False, max_depth=24, max_features=0.8, min_samples_leaf=7, min_samples_split=9, n_estimators=312; total time=   0.3s
# [CV] END bootstrap=False, max_depth=43, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=450; total time=   0.3s
# [CV] END bootstrap=False, max_depth=24, max_features=0.8, min_samples_leaf=7, min_samples_split=9, n_estimators=312; total time=   0.3s
# [CV] END bootstrap=False, max_depth=43, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=450; total time=   0.4s
# [CV] END bootstrap=False, max_depth=24, max_features=0.8, min_samples_leaf=7, min_samples_split=9, n_estimators=312; total time=   0.3s
# [CV] END bootstrap=False, max_depth=43, max_features=log2, min_samples_leaf=4, min_samples_split=15, n_estimators=450; total time=   0.5s
# [CV] END bootstrap=False, max_depth=27, max_features=0.6, min_samples_leaf=5, min_samples_split=14, n_estimators=140; total time=   0.1s
# [CV] END bootstrap=False, max_depth=27, max_features=0.6, min_samples_leaf=5, min_samples_split=14, n_estimators=140; total time=   0.1s
# [CV] END bootstrap=False, max_depth=27, max_features=0.6, min_samples_leaf=5, min_samples_split=14, n_estimators=140; total time=   0.1s
# [CV] END bootstrap=False, max_depth=27, max_features=0.6, min_samples_leaf=5, min_samples_split=14, n_estimators=140; total time=   0.1s
# [CV] END bootstrap=False, max_depth=27, max_features=0.6, min_samples_leaf=5, min_samples_split=14, n_estimators=140; total time=   0.1s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=108; total time=   0.2s
# [CV] END bootstrap=True, max_depth=24, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=108; total time=   0.1s
# [CV] END bootstrap=False, max_depth=24, max_features=0.8, min_samples_leaf=7, min_samples_split=9, n_estimators=312; total time=   0.3s
# [CV] END bootstrap=False, max_depth=24, max_features=0.8, min_samples_leaf=7, min_samples_split=9, n_estimators=312; total time=   0.3s
# [CV] END bootstrap=False, max_depth=10, max_features=0.8, min_samples_leaf=8, min_samples_split=12, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=0.8, min_samples_leaf=8, min_samples_split=12, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=0.8, min_samples_leaf=8, min_samples_split=12, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=0.8, min_samples_leaf=8, min_samples_split=12, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=10, max_features=0.8, min_samples_leaf=8, min_samples_split=12, n_estimators=180; total time=   0.2s
# [CV] END bootstrap=False, max_depth=44, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=330; total time=   0.3s
# [CV] END bootstrap=False, max_depth=44, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=330; total time=   0.3s
# [CV] END bootstrap=False, max_depth=44, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=330; total time=   0.4s
# [CV] END bootstrap=False, max_depth=44, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=330; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=0.6, min_samples_leaf=9, min_samples_split=9, n_estimators=367; total time=   0.3s
# [CV] END bootstrap=False, max_depth=44, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=330; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=0.6, min_samples_leaf=9, min_samples_split=9, n_estimators=367; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=0.6, min_samples_leaf=9, min_samples_split=9, n_estimators=367; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=0.6, min_samples_leaf=9, min_samples_split=9, n_estimators=367; total time=   0.3s
# [CV] END bootstrap=False, max_depth=42, max_features=0.8, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   0.2s
# [CV] END bootstrap=False, max_depth=42, max_features=0.8, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   0.2s
# [CV] END bootstrap=False, max_depth=37, max_features=0.6, min_samples_leaf=9, min_samples_split=9, n_estimators=367; total time=   0.3s
# [CV] END bootstrap=False, max_depth=42, max_features=0.8, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   0.2s
# [CV] END bootstrap=False, max_depth=42, max_features=0.8, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   0.2s
# [CV] END bootstrap=False, max_depth=42, max_features=0.8, min_samples_leaf=7, min_samples_split=6, n_estimators=198; total time=   0.2s
# [CV] END bootstrap=False, max_depth=49, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   0.3s
# [CV] END bootstrap=False, max_depth=49, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   0.3s
# [CV] END bootstrap=False, max_depth=49, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   0.3s
# [CV] END bootstrap=False, max_depth=49, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   0.3s
# [CV] END bootstrap=False, max_depth=49, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=326; total time=   0.3s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=9, min_samples_split=16, n_estimators=114; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=9, min_samples_split=16, n_estimators=114; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=9, min_samples_split=16, n_estimators=114; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=9, min_samples_split=16, n_estimators=114; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=9, min_samples_split=16, n_estimators=114; total time=   0.1s
# [CV] END bootstrap=False, max_depth=22, max_features=0.6, min_samples_leaf=7, min_samples_split=18, n_estimators=151; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=False, max_depth=22, max_features=0.6, min_samples_leaf=7, min_samples_split=18, n_estimators=151; total time=   0.1s
# [CV] END bootstrap=False, max_depth=22, max_features=0.6, min_samples_leaf=7, min_samples_split=18, n_estimators=151; total time=   0.1s
# [CV] END bootstrap=False, max_depth=22, max_features=0.6, min_samples_leaf=7, min_samples_split=18, n_estimators=151; total time=   0.1s
# [CV] END bootstrap=True, max_depth=23, max_features=0.6, min_samples_leaf=1, min_samples_split=6, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=False, max_depth=22, max_features=0.6, min_samples_leaf=7, min_samples_split=18, n_estimators=151; total time=   0.1s
# [CV] END bootstrap=True, max_depth=41, max_features=0.8, min_samples_leaf=5, min_samples_split=8, n_estimators=336; total time=   0.3s
# [CV] END bootstrap=True, max_depth=41, max_features=0.8, min_samples_leaf=5, min_samples_split=8, n_estimators=336; total time=   0.4s
# [CV] END bootstrap=True, max_depth=41, max_features=0.8, min_samples_leaf=5, min_samples_split=8, n_estimators=336; total time=   0.3s
# [CV] END bootstrap=True, max_depth=38, max_features=0.8, min_samples_leaf=7, min_samples_split=3, n_estimators=269; total time=   0.3s
# [CV] END bootstrap=True, max_depth=41, max_features=0.8, min_samples_leaf=5, min_samples_split=8, n_estimators=336; total time=   0.3s
# [CV] END bootstrap=True, max_depth=41, max_features=0.8, min_samples_leaf=5, min_samples_split=8, n_estimators=336; total time=   0.4s
# [CV] END bootstrap=True, max_depth=38, max_features=0.8, min_samples_leaf=7, min_samples_split=3, n_estimators=269; total time=   0.3s
# [CV] END bootstrap=True, max_depth=38, max_features=0.8, min_samples_leaf=7, min_samples_split=3, n_estimators=269; total time=   0.4s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=4, min_samples_split=12, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=4, min_samples_split=12, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=38, max_features=0.8, min_samples_leaf=7, min_samples_split=3, n_estimators=269; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=4, min_samples_split=12, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=4, min_samples_split=12, n_estimators=227; total time=   0.3s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=4, min_samples_split=12, n_estimators=227; total time=   0.3s
# [CV] END bootstrap=True, max_depth=38, max_features=0.8, min_samples_leaf=7, min_samples_split=3, n_estimators=269; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=484; total time=   0.4s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=484; total time=   0.3s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=484; total time=   0.3s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=484; total time=   0.4s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=7, min_samples_split=2, n_estimators=484; total time=   0.4s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.3s
# [CV] END bootstrap=True, max_depth=36, max_features=log2, min_samples_leaf=9, min_samples_split=14, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.3s
# [CV] END bootstrap=True, max_depth=48, max_features=log2, min_samples_leaf=8, min_samples_split=10, n_estimators=417; total time=   0.4s
# [CV] END bootstrap=True, max_depth=42, max_features=0.6, min_samples_leaf=8, min_samples_split=16, n_estimators=414; total time=   0.5s
# [CV] END bootstrap=True, max_depth=42, max_features=0.6, min_samples_leaf=8, min_samples_split=16, n_estimators=414; total time=   0.4s
# [CV] END bootstrap=False, max_depth=41, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=279; total time=   0.3s
# [CV] END bootstrap=True, max_depth=42, max_features=0.6, min_samples_leaf=8, min_samples_split=16, n_estimators=414; total time=   0.3s
# [CV] END bootstrap=False, max_depth=41, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=279; total time=   0.3s
# [CV] END bootstrap=True, max_depth=42, max_features=0.6, min_samples_leaf=8, min_samples_split=16, n_estimators=414; total time=   0.3s
# [CV] END bootstrap=True, max_depth=42, max_features=0.6, min_samples_leaf=8, min_samples_split=16, n_estimators=414; total time=   0.3s
# [CV] END bootstrap=False, max_depth=41, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=279; total time=   0.3s
# [CV] END bootstrap=False, max_depth=41, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=279; total time=   0.3s
# [CV] END bootstrap=False, max_depth=41, max_features=0.8, min_samples_leaf=8, min_samples_split=10, n_estimators=279; total time=   0.3s
# [CV] END bootstrap=True, max_depth=46, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=286; total time=   0.2s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=486; total time=   0.4s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=486; total time=   0.4s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=486; total time=   0.4s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=486; total time=   0.4s
# [CV] END bootstrap=True, max_depth=21, max_features=log2, min_samples_leaf=7, min_samples_split=3, n_estimators=486; total time=   0.4s
# [CV] END bootstrap=True, max_depth=46, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=286; total time=   0.2s
# [CV] END bootstrap=True, max_depth=46, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=286; total time=   0.2s
# [CV] END bootstrap=True, max_depth=46, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=286; total time=   0.2s
# [CV] END bootstrap=True, max_depth=46, max_features=sqrt, min_samples_leaf=8, min_samples_split=18, n_estimators=286; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=6, n_estimators=323; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=6, n_estimators=323; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=6, n_estimators=323; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.6, min_samples_leaf=2, min_samples_split=13, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=6, n_estimators=323; total time=   0.3s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, min_samples_split=6, n_estimators=323; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.6, min_samples_leaf=2, min_samples_split=13, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.6, min_samples_leaf=2, min_samples_split=13, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.6, min_samples_leaf=2, min_samples_split=13, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.6, min_samples_leaf=2, min_samples_split=13, n_estimators=317; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=0.8, min_samples_leaf=7, min_samples_split=5, n_estimators=302; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=0.8, min_samples_leaf=7, min_samples_split=5, n_estimators=302; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=0.8, min_samples_leaf=7, min_samples_split=5, n_estimators=302; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=0.8, min_samples_leaf=7, min_samples_split=5, n_estimators=302; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=0.8, min_samples_leaf=7, min_samples_split=5, n_estimators=302; total time=   0.4s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=223; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=223; total time=   0.2s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=223; total time=   0.2s
# [CV] END bootstrap=False, max_depth=26, max_features=0.6, min_samples_leaf=6, min_samples_split=6, n_estimators=471; total time=   0.4s
# [CV] END bootstrap=False, max_depth=26, max_features=0.6, min_samples_leaf=6, min_samples_split=6, n_estimators=471; total time=   0.4s
# [CV] END bootstrap=False, max_depth=26, max_features=0.6, min_samples_leaf=6, min_samples_split=6, n_estimators=471; total time=   0.4s
# [CV] END bootstrap=False, max_depth=26, max_features=0.6, min_samples_leaf=6, min_samples_split=6, n_estimators=471; total time=   0.3s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=223; total time=   0.2s
# [CV] END bootstrap=False, max_depth=26, max_features=0.6, min_samples_leaf=6, min_samples_split=6, n_estimators=471; total time=   0.4s
# [CV] END bootstrap=False, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=223; total time=   0.2s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=7, min_samples_split=10, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=7, min_samples_split=10, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=7, min_samples_split=10, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=3, min_samples_split=5, n_estimators=445; total time=   0.4s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=3, min_samples_split=5, n_estimators=445; total time=   0.5s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=3, min_samples_split=5, n_estimators=445; total time=   0.5s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=3, min_samples_split=5, n_estimators=445; total time=   0.5s
# [CV] END bootstrap=True, max_depth=15, max_features=0.8, min_samples_leaf=3, min_samples_split=5, n_estimators=445; total time=   0.6s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=7, min_samples_split=10, n_estimators=227; total time=   0.2s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=7, min_samples_split=10, n_estimators=227; total time=   0.3s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=1, min_samples_split=12, n_estimators=250; total time=   0.3s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=1, min_samples_split=12, n_estimators=250; total time=   0.2s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=1, min_samples_split=12, n_estimators=250; total time=   0.2s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=1, min_samples_split=12, n_estimators=250; total time=   0.3s
# [CV] END bootstrap=False, max_depth=35, max_features=0.8, min_samples_leaf=9, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=False, max_depth=35, max_features=0.8, min_samples_leaf=9, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=1, min_samples_split=12, n_estimators=250; total time=   0.3s
# [CV] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=351; total time=   0.3s
# [CV] END bootstrap=False, max_depth=35, max_features=0.8, min_samples_leaf=9, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=351; total time=   0.4s
# [CV] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=351; total time=   0.3s
# [CV] END bootstrap=False, max_depth=35, max_features=0.8, min_samples_leaf=9, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=351; total time=   0.3s
# [CV] END bootstrap=True, max_depth=39, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=351; total time=   0.4s
# [CV] END bootstrap=False, max_depth=35, max_features=0.8, min_samples_leaf=9, min_samples_split=18, n_estimators=101; total time=   0.1s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=332; total time=   0.2s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=3, min_samples_split=2, n_estimators=215; total time=   0.3s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=3, min_samples_split=2, n_estimators=215; total time=   0.2s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=3, min_samples_split=2, n_estimators=215; total time=   0.3s
# [CV] END bootstrap=True, max_depth=21, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=332; total time=   0.3s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=3, min_samples_split=2, n_estimators=215; total time=   0.3s
# [CV] END bootstrap=True, max_depth=28, max_features=0.8, min_samples_leaf=3, min_samples_split=2, n_estimators=215; total time=   0.3s
# [CV] END bootstrap=False, max_depth=44, max_features=0.8, min_samples_leaf=9, min_samples_split=4, n_estimators=252; total time=   0.3s
# [CV] END bootstrap=False, max_depth=44, max_features=0.8, min_samples_leaf=9, min_samples_split=4, n_estimators=252; total time=   0.3s
# [CV] END bootstrap=True, max_depth=17, max_features=0.8, min_samples_leaf=6, min_samples_split=9, n_estimators=439; total time=   0.4s
# [CV] END bootstrap=False, max_depth=44, max_features=0.8, min_samples_leaf=9, min_samples_split=4, n_estimators=252; total time=   0.2s
# [CV] END bootstrap=True, max_depth=17, max_features=0.8, min_samples_leaf=6, min_samples_split=9, n_estimators=439; total time=   0.4s
# [CV] END bootstrap=True, max_depth=17, max_features=0.8, min_samples_leaf=6, min_samples_split=9, n_estimators=439; total time=   0.4s
# [CV] END bootstrap=True, max_depth=17, max_features=0.8, min_samples_leaf=6, min_samples_split=9, n_estimators=439; total time=   0.5s
# [CV] END bootstrap=False, max_depth=44, max_features=0.8, min_samples_leaf=9, min_samples_split=4, n_estimators=252; total time=   0.3s
# [CV] END bootstrap=True, max_depth=17, max_features=0.8, min_samples_leaf=6, min_samples_split=9, n_estimators=439; total time=   0.6s
# [CV] END bootstrap=False, max_depth=44, max_features=0.8, min_samples_leaf=9, min_samples_split=4, n_estimators=252; total time=   0.2s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   0.2s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   0.2s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   0.2s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=2, min_samples_split=3, n_estimators=409; total time=   0.5s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=2, min_samples_split=3, n_estimators=409; total time=   0.5s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=2, min_samples_split=3, n_estimators=409; total time=   0.5s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   0.2s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=2, min_samples_split=3, n_estimators=409; total time=   0.5s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=9, min_samples_split=5, n_estimators=260; total time=   0.2s
# [CV] END bootstrap=True, max_depth=27, max_features=0.8, min_samples_leaf=2, min_samples_split=3, n_estimators=409; total time=   0.5s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=483; total time=   0.3s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=483; total time=   0.4s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=483; total time=   0.3s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=483; total time=   0.3s
# [CV] END bootstrap=False, max_depth=42, max_features=log2, min_samples_leaf=5, min_samples_split=17, n_estimators=483; total time=   0.3s
# The best hyperparameters: {'bootstrap': False, 'max_depth': 39, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 413}
# Best cross-verification R2 score: 0.8839
# Test set R2 score of optimised model: 0.8963
# Folder structure created: 'models/trained_models'
# Model başarıyla kaydedildi: models/trained_models/random_forest_airfoil_model.pkl

# %% [markdown]
# # Performans Scales

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.3f}")
print(f"MAE: {mae:.3f}")
print(f"R^2: {r2:.3f}")
# Out:
# RMSE: 2.266
# MAE: 1.643
# R^2: 0.897

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # 45 derece referans çizgisi
plt.show()

# %% [markdown]
# # Residual Plot

# %%
residuals = y_test - y_pred
plt.figure(figsize=(8,6))
sns.histplot(residuals, bins=30, kde=True)
plt.title("Residuals Distribution")
plt.xlabel("Residual")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=y_test, y=residuals)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Actual Values")
plt.show()
